# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 
import sklearn.metrics as metrics

# %%
df = pd.read_csv("Internship_data_1.csv")

# %%
df.head()
# Out:
#             time Cyclone_Inlet_Gas_Temp Cyclone_Material_Temp  \
# 0  1/1/2017 0:00                 867.63                910.42
# 1  1/1/2017 0:05                 879.23                918.14
# 2  1/1/2017 0:10                 875.67                924.18
# 3  1/1/2017 0:15                 875.28                923.15
# 4  1/1/2017 0:20                 891.66                934.26
#
#   Cyclone_Outlet_Gas_draft Cyclone_cone_draft Cyclone_Gas_Outlet_Temp  \
# 0                  -189.54            -186.04                  852.13
# 1                  -184.33             -182.1                  862.53
# 2                  -181.26            -166.47                  866.06
# 3                  -179.15            -174.83                  865.85
# 4                  -178.32            -173.72                  876.06
#
#   Cyclone_Inlet_Draft
# 0              -145.9
# 1             -149.76
# 2             -145.01
# 3             -142.82
# 4             -143.39

# %%
date = df['time']

# %%
df1 =df.drop_duplicates()

# %%
df1.shape
# Out:
# (377719, 7)

# %%
df1.isnull().value_counts()
# Out:
# time   Cyclone_Inlet_Gas_Temp  Cyclone_Material_Temp  Cyclone_Outlet_Gas_draft  Cyclone_cone_draft  Cyclone_Gas_Outlet_Temp  Cyclone_Inlet_Draft
# False  False                   False                  False                     False               False                    False                  377719
# dtype: int64

# %%
df1.describe()
# Out:
#                   time Cyclone_Inlet_Gas_Temp Cyclone_Material_Temp  \
# count           377719                 377719                377719
# unique          377719                  39736                 39662
# top     4/15/2017 5:25            Not Connect                     0
# freq                 1                    723                 14226
#
#        Cyclone_Outlet_Gas_draft Cyclone_cone_draft Cyclone_Gas_Outlet_Temp  \
# count                    377719             377719                  377719
# unique                    27669              26487                   48044
# top                 Not Connect        Not Connect                   28.88
# freq                        723                723                    2036
#
#        Cyclone_Inlet_Draft
# count               377719
# unique               24010
# top            Not Connect
# freq                   723

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 377719 entries, 0 to 377718
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   time                      377719 non-null  object
#  1   Cyclone_Inlet_Gas_Temp    377719 non-null  object
#  2   Cyclone_Material_Temp     377719 non-null  object
#  3   Cyclone_Outlet_Gas_draft  377719 non-null  object
#  4   Cyclone_cone_draft        377719 non-null  object
#  5   Cyclone_Gas_Outlet_Temp   377719 non-null  object
#  6   Cyclone_Inlet_Draft       377719 non-null  object
# dtypes: object(7)
# memory usage: 23.1+ MB

# %%
Cyclone_Inlet_Gas_Temp = []
Cyclone_Material_Temp = []
Cyclone_Outlet_Gas_draft = []
Cyclone_cone_draft =[]
Cyclone_Gas_Outlet_Temp = []
Cyclone_Inlet_Draft = []




for i in df['Cyclone_Inlet_Gas_Temp']:
    if i=='I/O Timeout' or i == 'Not Connect' or i == 'Configure' or i =="Scan Timeout" or i == 'Comm Fail' or i=='Unit Down':
        Cyclone_Inlet_Gas_Temp.append(0)
    else:
        Cyclone_Inlet_Gas_Temp.append(i)

for i in df['Cyclone_Material_Temp']:
    if i=='I/O Timeout' or i == 'Not Connect' or i == 'Configure' or i =="Scan Timeout" or i == 'Comm Fail' or i=='Unit Down':
        Cyclone_Material_Temp.append(0)
    else:
        Cyclone_Material_Temp.append(i)

for i in df['Cyclone_Outlet_Gas_draft']:
    if i=='I/O Timeout' or i == 'Not Connect' or i == 'Configure' or i =="Scan Timeout" or i == 'Comm Fail' or i=='Unit Down':
        Cyclone_Outlet_Gas_draft.append(0)
    else:
        Cyclone_Outlet_Gas_draft.append(i)

for i in df['Cyclone_cone_draft']:
    if i=='I/O Timeout' or i == 'Not Connect' or i == 'Configure' or i =="Scan Timeout" or i == 'Comm Fail' or i=='Unit Down':
        Cyclone_cone_draft.append(0)
    else:
        Cyclone_cone_draft.append(i)    
        

for i in df['Cyclone_Gas_Outlet_Temp']:
    if i=='I/O Timeout' or i == 'Not Connect' or i == 'Configure' or i =="Scan Timeout" or i == 'Comm Fail' or i=='Unit Down':
        Cyclone_Gas_Outlet_Temp.append(0)
    else:
        Cyclone_Gas_Outlet_Temp.append(i)
        
for i in df['Cyclone_Inlet_Draft']:
    if i=='I/O Timeout' or i == 'Not Connect' or i == 'Configure' or i =="Scan Timeout" or i == 'Comm Fail' or i=='Unit Down':
        Cyclone_Inlet_Draft.append(0)
    else:
        Cyclone_Inlet_Draft.append(i)

# %%
date = []
for i in df['time']:
    date1 = i.replace("/", "").replace(":", "").replace(" ","")
    date.append(date1)

# %%
newdata = {"Cyclone_Inlet_Gas_Temp":Cyclone_Inlet_Gas_Temp,"Cyclone_Material_Temp":Cyclone_Material_Temp,"Cyclone_Outlet_Gas_draft":Cyclone_Outlet_Gas_draft,'Cyclone_cone_draft':Cyclone_cone_draft,"Cyclone_Gas_Outlet_Temp":Cyclone_Gas_Outlet_Temp,'Cyclone_Inlet_Draft':Cyclone_Inlet_Draft}

# %%
dfnew = pd.DataFrame(newdata)

# %%
dfdup = dfnew.drop_duplicates()

# %%
dfdup
# Out:
#        Cyclone_Inlet_Gas_Temp Cyclone_Material_Temp Cyclone_Outlet_Gas_draft  \
# 0                      867.63                910.42                  -189.54
# 1                      879.23                918.14                  -184.33
# 2                      875.67                924.18                  -181.26
# 3                      875.28                923.15                  -179.15
# 4                      891.66                934.26                  -178.32
# ...                       ...                   ...                      ...
# 377714                 899.42                919.79                  -224.07
# 377715                  879.9                895.02                  -228.04
# 377716                  887.2                 895.7                  -230.11
# 377717                  908.5                916.33                  -231.51
# 377718                 880.86                905.31                  -235.02
#
# ...

# %%
dfdup.shape
# Out:
# (375627, 6)

# %% [markdown]
# # Cyclone_Inlet_Outlet_Gas_Temp
#
# # cyclone outlet gas temperature is increasing as increasing the temparature of inlet gas

# %%
Cyclone_Inlet_Gas_Temp =dfdup['Cyclone_Inlet_Gas_Temp'].value_counts()
Cyclone_Gas_Outlet_Temp =dfdup['Cyclone_Gas_Outlet_Temp'].value_counts()
plt.figure(figsize=(20,5))
sns.boxplot(x = Cyclone_Gas_Outlet_Temp,y = Cyclone_Inlet_Gas_Temp)
plt.show()

# %% [markdown]
# # pressure is much higher in cone section rather than inlet and oulet draft

# %%
Cyclone_Inlet_Draft =dfdup['Cyclone_Inlet_Draft'].value_counts()
Cyclone_cone_draft =dfdup['Cyclone_cone_draft'].value_counts()
plt.figure(figsize=(20,8))
sns.barplot(x=Cyclone_Inlet_Draft,y = Cyclone_cone_draft)
plt.show()

# %%
Cyclone_Inlet_Draft =dfdup['Cyclone_Inlet_Draft'].value_counts()
Cyclone_cone_draft =dfdup['Cyclone_cone_draft'].value_counts()
plt.figure(figsize=(20,8))
sns.boxplot(x=Cyclone_Inlet_Draft,y = Cyclone_cone_draft)
plt.show()

# %%
Cyclone_Outlet_Gas_draft =dfdup['Cyclone_Outlet_Gas_draft'].value_counts()
Cyclone_cone_draft =dfdup['Cyclone_cone_draft'].value_counts()
plt.figure(figsize=(20,8))
sns.barplot(x=Cyclone_Outlet_Gas_draft,y = Cyclone_cone_draft)
plt.show()

# %%
Cyclone_Inlet_Draft =dfdup['Cyclone_Inlet_Draft'].value_counts()
Cyclone_Outlet_Gas_draft =dfdup['Cyclone_Outlet_Gas_draft'].value_counts()
plt.figure(figsize=(20,5))
sns.boxplot(x = Cyclone_Inlet_Draft,y = Cyclone_Outlet_Gas_draft)
plt.show()

# %%
Cyclone_Inlet_Draft =dfdup['Cyclone_Inlet_Draft'].value_counts()
Cyclone_Outlet_Gas_draft =dfdup['Cyclone_Outlet_Gas_draft'].value_counts()
plt.figure(figsize=(20,8))
sns.barplot(x=Cyclone_Inlet_Draft,y = Cyclone_Outlet_Gas_draft)
plt.show()

# %% [markdown]
# # material temprature show some abnormality

# %%
Cyclone_Gas_Outlet_Temp =dfdup['Cyclone_Gas_Outlet_Temp'].value_counts()
Cyclone_Material_Temp  =dfdup['Cyclone_Material_Temp'].value_counts()
plt.figure(figsize=(20,8))
sns.barplot(x = Cyclone_Material_Temp,y=Cyclone_Gas_Outlet_Temp)
plt.show()

# %%
Cyclone_Outlet_Gas_draft =dfdup['Cyclone_Outlet_Gas_draft'].value_counts()
Cyclone_Material_Temp  =dfdup['Cyclone_Material_Temp'].value_counts()
plt.figure(figsize=(20,8))
sns.barplot(x=Cyclone_Outlet_Gas_draft,y = Cyclone_Material_Temp)
plt.show()

# %% [markdown]
# # Cyclone_Outlet_Gas_draft decreasing as increasing the Cyclone_Gas_Outlet_Temp

# %%
Cyclone_Outlet_Gas_draft =dfdup['Cyclone_Outlet_Gas_draft'].value_counts()
Cyclone_Gas_Outlet_Temp  =dfdup['Cyclone_Gas_Outlet_Temp'].value_counts()
plt.figure(figsize=(20,8))
sns.barplot(y=Cyclone_Outlet_Gas_draft,x = Cyclone_Gas_Outlet_Temp)
plt.show()

# %%
dfdup['Cyclone_Inlet_Gas_Temp'].value_counts()
# Out:
# 23.53     309
# 820       116
# 29.97      92
# 32.65      90
# 31.74      89
#          ...
# 355.3       1
# 274.67      1
# 817.19      1
# 626.58      1
# 0           1
# Name: Cyclone_Inlet_Gas_Temp, Length: 39732, dtype: int64

# %%
dfdup['Cyclone_Material_Temp'].value_counts()
# Out:
# 0          14180
# 94.31       3669
# 59.56       3409
# 41.64       2865
# 43.14       2829
#            ...
# 1035.05        1
# 1074.44        1
# 526.42         1
# 645.89         1
# 1011.19        1
# Name: Cyclone_Material_Temp, Length: 39657, dtype: int64

# %%
dfdup['Cyclone_Outlet_Gas_draft'].value_counts()
# Out:
# 1.33       224
# 1.71       220
# 1.34       212
# 1.36       211
# 1.75       210
#           ...
# -52.98       1
# -145.12      1
# -72.42       1
# -42.06       1
# -116.61      1
# Name: Cyclone_Outlet_Gas_draft, Length: 27664, dtype: int64

# %%
dfdup['Cyclone_Gas_Outlet_Temp'].value_counts()
# Out:
# 28.88      2031
# 24.69       304
# 661.19      197
# 206.37      135
# 31.5         93
#            ...
# 1003.96       1
# 186.34        1
# 274.37        1
# 802.9         1
# 403.56        1
# Name: Cyclone_Gas_Outlet_Temp, Length: 48039, dtype: int64

# %%
dfdup['Cyclone_Inlet_Draft'].value_counts()
# Out:
# -1.49      282
# -1.71      276
# -1.46      276
# -1.35      274
# -1.39      272
#           ...
# -31.9        1
# -57.33       1
# -246.23      1
# -69.2        1
# -256.56      1
# Name: Cyclone_Inlet_Draft, Length: 24005, dtype: int64

# %%
dfdup.head()
# Out:
#   Cyclone_Inlet_Gas_Temp Cyclone_Material_Temp Cyclone_Outlet_Gas_draft  \
# 0                 867.63                910.42                  -189.54
# 1                 879.23                918.14                  -184.33
# 2                 875.67                924.18                  -181.26
# 3                 875.28                923.15                  -179.15
# 4                 891.66                934.26                  -178.32
#
#   Cyclone_cone_draft Cyclone_Gas_Outlet_Temp Cyclone_Inlet_Draft
# 0            -186.04                  852.13              -145.9
# 1             -182.1                  862.53             -149.76
# 2            -166.47                  866.06             -145.01
# 3            -174.83                  865.85             -142.82
# 4            -173.72                  876.06             -143.39

# %%
X = dfdup[['Cyclone_Inlet_Gas_Temp','Cyclone_Material_Temp','Cyclone_Outlet_Gas_draft','Cyclone_Gas_Outlet_Temp','Cyclone_Inlet_Draft']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,date[0:375627],test_size=0.3)

# %% [markdown]
# # Model 1 linear regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
y_test[0:5]
y_pred[0:5]
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# c:\users\harish\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)
# 1.2892248663249078e+21

# %% [markdown]
# # Model 2 desion tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtc= DecisionTreeClassifier()
dtc.fit(x_train,y_train)
DecisionTreeClassifier()
y_pred=dtc.predict(x_test)
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))
